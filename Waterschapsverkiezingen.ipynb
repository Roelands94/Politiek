# %% [markdown]
# ## Total

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
uitslag=pd.read_csv('waterschap2019', delimiter=',', index_col = 0)
uitslag['Hulst']=uitslag['ST1']+uitslag['ST2']+uitslag['ST3']+uitslag["ST4"]
dummies = pd.get_dummies(uitslag['Partij'])
uitslag = uitslag.merge(dummies, left_index=True, right_index= True)
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.Totaal[uitslag.CDA==1].sum(),uitslag.Totaal[uitslag.SGP==1].sum(),uitslag.Totaal[uitslag.WPZV==1].sum(),uitslag.Totaal[uitslag.PVZ==1].sum(),uitslag.Totaal[uitslag.VVD==1].sum(),uitslag.Totaal[uitslag.PVDA==1].sum(),uitslag.Totaal[uitslag.WN==1].sum(),uitslag.Totaal[uitslag.CU==1].sum(),uitslag.Totaal[uitslag.VP==1].sum(),uitslag.Totaal[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=23
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    9
# CDA     7
# PVDA    2
# 50P     2
# WN      1
# VVD     1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Hulst

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.Hulst[uitslag.CDA==1].sum(),uitslag.Hulst[uitslag.SGP==1].sum(),uitslag.Hulst[uitslag.WPZV==1].sum(),uitslag.Hulst[uitslag.PVZ==1].sum(),uitslag.Hulst[uitslag.VVD==1].sum(),uitslag.Hulst[uitslag.PVDA==1].sum(),uitslag.Hulst[uitslag.WN==1].sum(),uitslag.Hulst[uitslag.CU==1].sum(),uitslag.Hulst[uitslag.VP==1].sum(),uitslag.Hulst[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# CDA     7
# WPZV    7
# PVDA    2
# 50P     2
# WN      1
# VVD     1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Clinge

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST5[uitslag.CDA==1].sum(),uitslag.ST5[uitslag.SGP==1].sum(),uitslag.ST5[uitslag.WPZV==1].sum(),uitslag.ST5[uitslag.PVZ==1].sum(),uitslag.ST5[uitslag.VVD==1].sum(),uitslag.ST5[uitslag.PVDA==1].sum(),uitslag.ST5[uitslag.WN==1].sum(),uitslag.ST5[uitslag.CU==1].sum(),uitslag.ST5[uitslag.VP==1].sum(),uitslag.ST5[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# CDA     5
# WPZV    5
# PVZ     4
# 50P     3
# PVDA    3
# WN      1
# Name: Partij, dtype: int64

# %% [markdown]
# # Nieuw-Namen

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST6[uitslag.CDA==1].sum(),uitslag.ST6[uitslag.SGP==1].sum(),uitslag.ST6[uitslag.WPZV==1].sum(),uitslag.ST6[uitslag.PVZ==1].sum(),uitslag.ST6[uitslag.VVD==1].sum(),uitslag.ST6[uitslag.PVDA==1].sum(),uitslag.ST6[uitslag.WN==1].sum(),uitslag.ST6[uitslag.CU==1].sum(),uitslag.ST6[uitslag.VP==1].sum(),uitslag.ST6[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# CDA     10
# WPZV     5
# 50P      2
# PVDA     1
# VVD      1
# AWP      1
# PVZ      1
# Name: Partij, dtype: int64

# %% [markdown]
# # Graauw

# %%
uitslag=uitslag.rename(columns={'ST 7':'ST7'})
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST7[uitslag.CDA==1].sum(),uitslag.ST7[uitslag.SGP==1].sum(),uitslag.ST7[uitslag.WPZV==1].sum(),uitslag.ST7[uitslag.PVZ==1].sum(),uitslag.ST7[uitslag.VVD==1].sum(),uitslag.ST7[uitslag.PVDA==1].sum(),uitslag.ST7[uitslag.WN==1].sum(),uitslag.ST7[uitslag.CU==1].sum(),uitslag.ST7[uitslag.VP==1].sum(),uitslag.ST7[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# CDA     10
# WPZV     6
# WN       2
# 50P      1
# PVDA     1
# PVZ      1
# Name: Partij, dtype: int64

# %% [markdown]
# # Sint Jansteen

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST8[uitslag.CDA==1].sum(),uitslag.ST8[uitslag.SGP==1].sum(),uitslag.ST8[uitslag.WPZV==1].sum(),uitslag.ST8[uitslag.PVZ==1].sum(),uitslag.ST8[uitslag.VVD==1].sum(),uitslag.ST8[uitslag.PVDA==1].sum(),uitslag.ST8[uitslag.WN==1].sum(),uitslag.ST8[uitslag.CU==1].sum(),uitslag.ST8[uitslag.VP==1].sum(),uitslag.ST8[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    8
# CDA     6
# 50P     3
# PVDA    1
# WN      1
# VVD     1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Heikant

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST9[uitslag.CDA==1].sum(),uitslag.ST9[uitslag.SGP==1].sum(),uitslag.ST9[uitslag.WPZV==1].sum(),uitslag.ST9[uitslag.PVZ==1].sum(),uitslag.ST9[uitslag.VVD==1].sum(),uitslag.ST9[uitslag.PVDA==1].sum(),uitslag.ST9[uitslag.WN==1].sum(),uitslag.ST9[uitslag.CU==1].sum(),uitslag.ST9[uitslag.VP==1].sum(),uitslag.ST9[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# CDA     7
# WPZV    7
# PVDA    2
# 50P     2
# WN      1
# VVD     1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Kloosterzande

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST10[uitslag.CDA==1].sum(),uitslag.ST10[uitslag.SGP==1].sum(),uitslag.ST10[uitslag.WPZV==1].sum(),uitslag.ST10[uitslag.PVZ==1].sum(),uitslag.ST10[uitslag.VVD==1].sum(),uitslag.ST10[uitslag.PVDA==1].sum(),uitslag.ST10[uitslag.WN==1].sum(),uitslag.ST10[uitslag.CU==1].sum(),uitslag.ST10[uitslag.VP==1].sum(),uitslag.ST10[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    12
# CDA      6
# 50P      1
# PVDA     1
# PVZ      1
# Name: Partij, dtype: int64

# %% [markdown]
# # Lamswaarde

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST11[uitslag.CDA==1].sum(),uitslag.ST11[uitslag.SGP==1].sum(),uitslag.ST11[uitslag.WPZV==1].sum(),uitslag.ST11[uitslag.PVZ==1].sum(),uitslag.ST11[uitslag.VVD==1].sum(),uitslag.ST11[uitslag.PVDA==1].sum(),uitslag.ST11[uitslag.WN==1].sum(),uitslag.ST11[uitslag.CU==1].sum(),uitslag.ST11[uitslag.VP==1].sum(),uitslag.ST11[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    12
# CDA      6
# 50P      1
# PVDA     1
# WN       1
# Name: Partij, dtype: int64

# %% [markdown]
# # Terhole

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST12[uitslag.CDA==1].sum(),uitslag.ST12[uitslag.SGP==1].sum(),uitslag.ST12[uitslag.WPZV==1].sum(),uitslag.ST12[uitslag.PVZ==1].sum(),uitslag.ST12[uitslag.VVD==1].sum(),uitslag.ST12[uitslag.PVDA==1].sum(),uitslag.ST12[uitslag.WN==1].sum(),uitslag.ST12[uitslag.CU==1].sum(),uitslag.ST12[uitslag.VP==1].sum(),uitslag.ST12[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    9
# CDA     5
# PVDA    2
# 50P     2
# WN      1
# AWP     1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Vogelwaarde

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST13[uitslag.CDA==1].sum(),uitslag.ST13[uitslag.SGP==1].sum(),uitslag.ST13[uitslag.WPZV==1].sum(),uitslag.ST13[uitslag.PVZ==1].sum(),uitslag.ST13[uitslag.VVD==1].sum(),uitslag.ST13[uitslag.PVDA==1].sum(),uitslag.ST13[uitslag.WN==1].sum(),uitslag.ST13[uitslag.CU==1].sum(),uitslag.ST13[uitslag.VP==1].sum(),uitslag.ST13[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    9
# CDA     6
# PVDA    3
# 50P     1
# WN      1
# PVZ     1
# Name: Partij, dtype: int64

# %% [markdown]
# # Ossenisse

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST14[uitslag.CDA==1].sum(),uitslag.ST14[uitslag.SGP==1].sum(),uitslag.ST14[uitslag.WPZV==1].sum(),uitslag.ST14[uitslag.PVZ==1].sum(),uitslag.ST14[uitslag.VVD==1].sum(),uitslag.ST14[uitslag.PVDA==1].sum(),uitslag.ST14[uitslag.WN==1].sum(),uitslag.ST14[uitslag.CU==1].sum(),uitslag.ST14[uitslag.VP==1].sum(),uitslag.ST14[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    10
# CDA      6
# PVZ      2
# 50P      1
# PVDA     1
# WN       1
# Name: Partij, dtype: int64

# %% [markdown]
# # Hengstdijk

# %%
uitslagpartij= {'Partij':['CDA', 'SGP', 'WPZV', 'PVZ', 'VVD', 'PVDA', 'WN','CU', '50P', 'AWP'], 'x':[uitslag.ST15[uitslag.CDA==1].sum(),uitslag.ST15[uitslag.SGP==1].sum(),uitslag.ST15[uitslag.WPZV==1].sum(),uitslag.ST15[uitslag.PVZ==1].sum(),uitslag.ST15[uitslag.VVD==1].sum(),uitslag.ST15[uitslag.PVDA==1].sum(),uitslag.ST15[uitslag.WN==1].sum(),uitslag.ST15[uitslag.CU==1].sum(),uitslag.ST15[uitslag.VP==1].sum(),uitslag.ST15[uitslag.AWP==1].sum()]}
up=pd.DataFrame(data=uitslagpartij)
quo = {'Partij':[], 'quotient':[]}
quotient=pd.DataFrame()
seats=21
i=1
while i<seats:
    up.insert(i,'quotient',up.x/i,allow_duplicates=True)
    def a(i):
        return pd.DataFrame(up.iloc[:,[0,i]])
    quotient=quotient.append(a(i),ignore_index=True)
    i+=1
zetels= quotient.nlargest(seats,'quotient', keep='first')
zetelverdeling=zetels['Partij'].value_counts()
labels= zetelverdeling.index
ay=plt.pie(zetelverdeling, labels=labels, shadow=True)
plt.show()
print(zetelverdeling)
# Out:
# WPZV    9
# CDA     6
# 50P     2
# PVDA    1
# WN      1
# AWP     1
# PVZ     1
# Name: Partij, dtype: int64
